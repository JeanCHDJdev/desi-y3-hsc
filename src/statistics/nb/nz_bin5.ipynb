# %% [markdown]
# ## `nz_bin5.ipynb`
# -------------
#
# The goal of this notebook is to combine the measurements from auto-correlations and cross-correlation for the study performed in appendix B of the n(z) paper. Environment to use : `desi`

# %%
import numpy as np
import importlib
import matplotlib.pyplot as plt
import pandas as pd
import json
import scipy.interpolate as interp
import fitsio as fio

from datetime import datetime
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.ticker import MultipleLocator
from pathlib import Path
from scipy.integrate import simpson
from pycorr import TwoPointEstimator

import src.statistics.inference as inference
import src.statistics.combination as comb
import src.analysis.plots as plots
import src.statistics.cosmotools as ct
import src.statistics.corrfiles as cf
import src.statistics.sgp as sgp

ROOT = cf.get_base_dir()
CORR_ROOT = ROOT / "src" / "statistics" / "outputs"
bins_hsc = np.arange(1.8, 2.1, 0.2)

RESULTS_ROOT = ROOT / "results"
Path(RESULTS_ROOT).mkdir(parents=True, exist_ok=True)

PAPER_FIGURES_ROOT = Path(
    "/global/cfs/projectdirs/desi/users/jchdj/desi-y3-hsc/paper/figures/"
)
pm = plots.PlotManager(root=PAPER_FIGURES_ROOT, overwrite=True)

# %%
## Denisties for appendix B
hsc = fio.FITS(
    f"{ROOT}/data/hsc/cat/hscy3_cat_withflags.fits"
)[1].read()
photoz = hsc["dnnz_photoz_best"]
## we take a look at a 5th tomographic bin (1.8 < z < 2.0) in order to look at QSO sensitivity
## for higher redshift sources.
fifth_bin = hsc[(photoz >= 1.8) & (photoz < 2.0)]
## now we compute the density of sources, knowing the surface of the HSC footprint is 416 deg2
fifth_bin_density = len(fifth_bin) / 416.0
print(f"Fifth bin (1.8 < z < 2.0) density: {fifth_bin_density:.2f} sources per deg2")
# we downsample the fifth bin to 20% of its original density
fifth_bin_downsampled = fifth_bin[np.random.choice(fifth_bin.shape[0], size=int(0.25 * fifth_bin.shape[0]), replace=False)]
print(f"Downsampled fifth bin (1.8 < z < 2.0) density: {len(fifth_bin_downsampled) / 416.0:.2f} sources per deg2")
# in arcmin2
print(f"Fifth bin (1.8 < z < 2.0) density: {fifth_bin_density / 3600.0:.4f} sources per arcmin2")
print(f"Downsampled fifth bin (1.8 < z < 2.0) density: {len(fifth_bin_downsampled) / (416.0 * 3600.0):.6f} sources per arcmin2")
# Out:
# Fifth bin (1.8 < z < 2.0) density: 1430.63 sources per deg2
# Downsampled fifth bin (1.8 < z < 2.0) density: 357.66 sources per deg2
# Fifth bin (1.8 < z < 2.0) density: 0.3974 sources per arcmin2
# Downsampled fifth bin (1.8 < z < 2.0) density: 0.099349 sources per arcmin2

# %%
markers = ["x", "s", "^", "D"]
linestyles = ["-", "--", "-.", ":"]
colormaps = [plt.get_cmap(c) for c in ["Reds", "Blues", "Greens", "Purples"]]
colors = [cmap(0.8) for cmap in colormaps]
tracers = ["BGS_ANY", "LRG", "ELGnotqso", "QSO"]
tracer_trad = {
    "BGS_ANY": "BGS",
    "LRG": "LRG",
    "ELGnotqso": "ELG",
    "QSO": "QSO",
}
stem = "dr2"
path_dictionary = {
    "HSC": CORR_ROOT / "v12_correction" / f"autos_HSC",  # unused in practice
    "DESI_NGC": CORR_ROOT / "dr2" / f"autos_NGC",
    "DESI_SGC": CORR_ROOT / "dr2" / f"autos_SGC",
    "DESIxHSC": CORR_ROOT / "calibration_bin5" / "dr2" / f"cross",
}
fr = cf.CorrFileReader(path_dictionary["DESIxHSC"])

do_phot_correction = True
do_spec_correction = True

scale_cut = [1, 5]
version = "vBin5"

print(f"Scale cut: {scale_cut[0]} - {scale_cut[1]} Mpc/h")

# which tracers to use in inference
tomo_to_tracer = {
    1: ["QSO"],
}
# which patches to use in inference
patches = [1, 2, 3, 4]
# Out:
# Scale cut: 1 - 5 Mpc/h

# %%
## precompute w_dm
importlib.reload(inference)
bins_z_spectro = np.arange(0.7, 2.85, 0.05)
vals_z_spectro = (bins_z_spectro[:-1] + bins_z_spectro[1:]) / 2
vals_z_wdm = np.linspace(0.01, 3, 150)
rp_wdm = np.linspace(scale_cut[0], scale_cut[1], 100)
wdm_values = np.array(
    [
        ct.w_dm(
            rp_vals=rp_wdm,
            z=z,  # compute w_dm centered at redshift z
            integrate=True,  # integrate over the scale cuts provided (so on rp_vals)
        )
        for z in vals_z_wdm
    ]
)
wdm_interpolator = interp.interp1d(
    vals_z_wdm, wdm_values, bounds_error=False, fill_value="extrapolate"
)

# %%
# this is for npz_cross, we merge directly on tracers due to amplitude differences.
importlib.reload(inference)
for tomo in [1]:
    stem = "calibration_bin5/dr2"
    print(f"=== Tomographic bin {tomo} ===")
    path_dictionary = {
        "HSC": CORR_ROOT / "v12_correction" / f"autos_HSC",  # unused in practice
        "DESI_NGC": CORR_ROOT / stem / f"autos_NGC",
        "DESI_SGC": CORR_ROOT / stem / f"autos_SGC",
        "DESIxHSC": CORR_ROOT / stem / f"cross",
        "MergedxMerged": CORR_ROOT / f"merged_{stem}_{version}",
        "MergedxHSC": CORR_ROOT / f"merged_{stem}_{version}",
    }
    inference.merge_estimators(
        path_dictionary=path_dictionary,
        which_tomo=[tomo],
        outdir=path_dictionary["MergedxMerged"],  # where to save results
        which_tracers=tomo_to_tracer[tomo],
    )
# Out:
# === Tomographic bin 1 ===
# Processing redshift bin 0 (Completion : 2.33%)
# Processing redshift bin 4 (Completion : 11.63%)
# Processing redshift bin 8 (Completion : 20.93%)
# Processing redshift bin 12 (Completion : 30.23%)
# Processing redshift bin 16 (Completion : 39.53%)
# Processing redshift bin 20 (Completion : 48.84%)
# Processing redshift bin 24 (Completion : 58.14%)
# Processing redshift bin 28 (Completion : 67.44%)
# Processing redshift bin 32 (Completion : 76.74%)
# Processing redshift bin 36 (Completion : 86.05%)
# Processing redshift bin 40 (Completion : 95.35%)
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x1_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x1_b2x1.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x2_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x2_b2x2.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x3_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x3_b2x3.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x4_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x4_b2x4.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x5_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x5_b2x5.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x6_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x6_b2x6.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x7_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x7_b2x7.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x8_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x8_b2x8.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x9_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x9_b2x9.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x10_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x10_b2x10.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x11_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x11_b2x11.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x12_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x12_b2x12.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x13_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x13_b2x13.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x14_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x14_b2x14.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x15_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x15_b2x15.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x16_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x16_b2x16.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x17_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x17_b2x17.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x18_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x18_b2x18.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x19_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x19_b2x19.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x20_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x20_b2x20.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x21_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x21_b2x21.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x22_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x22_b2x22.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x23_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x23_b2x23.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x24_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x24_b2x24.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x25_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x25_b2x25.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x26_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x26_b2x26.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x27_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x27_b2x27.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x28_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x28_b2x28.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x29_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x29_b2x29.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x30_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x30_b2x30.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x31_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x31_b2x31.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x32_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x32_b2x32.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x33_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x33_b2x33.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x34_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x34_b2x34.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x35_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x35_b2x35.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x36_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x36_b2x36.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x37_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x37_b2x37.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x38_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x38_b2x38.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x39_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x39_b2x39.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x40_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x40_b2x40.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x41_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x41_b2x41.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x42_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x42_b2x42.npy
# Saved cross-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxHSC/MergedxHSC_b1x43_b2x1.npy
# Saved auto-correlation estimator to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/src/statistics/outputs/merged_calibration_bin5/dr2_vBin5/MergedxMerged/MergedxMerged_b1x43_b2x43.npy

# %%
importlib.reload(inference)
importlib.reload(ct)
print("\nScale cuts : ", scale_cut, "\n")

npzs = [
    {k: [] for k in [1, 2, 3, 4]} for _ in range(4)
]  # no correction, only spec, both spec and bias, both spec & bias & mag
npz_errs = [{k: [] for k in [1, 2, 3, 4]} for _ in range(4)]
zvals = [{k: [] for k in [1, 2, 3, 4]} for _ in range(4)]

for ic, condition in enumerate(
    [
        (False, False, False),  # no correction
        (False, True, False),  # only spec correction
        (True, True, False),  # with bias and spec correction
        (True, True, True),  # with magnification
    ]
):
    do_phot_correction, do_spec_correction, do_mag = condition
    for tomo in [1]:
        stem = "calibration_bin5/dr2"
        path_dictionary = {
            "HSC": CORR_ROOT / "v12_correction" / f"autos_HSC",  # unused in practice
            "DESI_NGC": CORR_ROOT / stem / f"autos_NGC",
            "DESI_SGC": CORR_ROOT / stem / f"autos_SGC",
            "DESIxHSC": CORR_ROOT / stem / f"cross",
            "MergedxMerged": CORR_ROOT / f"merged_{stem}_{version}",
            "MergedxHSC": CORR_ROOT / f"merged_{stem}_{version}",
        }
        fr = cf.CorrFileReader(path_dictionary["DESIxHSC"])
        if condition == (False, False, False):
            # we fuse estimators for the no correction case because of amplitude differences for each tracer...
            # just makes it easier to compare. These are made with the "merged" files
            meas = inference.full_npz_tomo(
                path_dictionary=path_dictionary,
                do_phot_correction=do_phot_correction,
                do_spec_correction=do_spec_correction,
                scale_cuts=scale_cut,
                tomo_bin=tomo,
                tracer="QSO",
                which_patches=None,  # they have already been fused together
                precomp_wdm=wdm_interpolator,
            )
            npzs[ic][tomo].append(meas[0])
            npz_errs[ic][tomo].append(meas[1])
            zbins = inference._get_fine_redshift_bins(fr, tracer="QSO")
            _zvals = (zbins[:-1] + zbins[1:]) / 2
            zvals[ic][tomo].append(_zvals)
        else:
            for ind, tracer in enumerate(tomo_to_tracer[tomo]):

                zbins = fr.get_bins(tracer)
                _zvals = (zbins[:-1] + zbins[1:]) / 2
                meas = inference.full_npz_tomo(
                    path_dictionary=path_dictionary,
                    do_phot_correction=do_phot_correction,
                    do_spec_correction=do_spec_correction,
                    scale_cuts=scale_cut,
                    tomo_bin=tomo,
                    tracer=tracer,
                    which_patches=patches,
                    precomp_wdm=wdm_interpolator,
                )
                if do_mag == True:
                    _npz, _npz_err, wdm, Mag, dMag = ct.solve_magnification(
                        meas=meas,
                        tracer=tracer,
                        tomo_bin=tomo,
                        scale_cut=scale_cut,
                        zvalues=_zvals,
                        return_matrices=True,
                    )
                    meas = (_npz, _npz_err)

                zvals[ic][tomo].append(_zvals)
                npzs[ic][tomo].append(meas[0])
                npz_errs[ic][tomo].append(meas[1])
# Out:
# Scale cuts :  [1, 5]
#
# Using standard method for tracer QSO and tomo bin 1.
# Using standard method for tracer QSO and tomo bin 1.
# Using standard method for tracer QSO and tomo bin 1.
# Using standard method for tracer QSO and tomo bin 1.

# %%
RESULTS_ROOT = ROOT / "results" / "calibration_bin5"
Path(RESULTS_ROOT).mkdir(parents=True, exist_ok=True)
data_rows = []

for tomo in [1]:
    # --- "Merged" cases (cross)
    z_vals_cross = zvals[0][tomo][0]
    nz_cross = npzs[0][tomo][0]
    nz_cross_err = npz_errs[0][tomo][0]

    for j in range(len(z_vals_cross)):
        data_rows.append(
            {
                "tomo_bin": tomo,
                "tracer": "Merged",
                "redshift": z_vals_cross[j],
                "npz_cross": nz_cross[j],
                "npz_cross_err": nz_cross_err[j],
                "npz_bs_bp": None,
                "npz_bs_bp_err": None,
                "npz_bs_bp_mag": None,
                "npz_bs_bp_mag_err": None,
            }
        )

    # --- per-tracer cases (bs_bp & bs_bp_mag)
    for i, tracer in enumerate(tomo_to_tracer[tomo]):
        z_vals_bs = zvals[1][tomo][i]
        nz_bs = npzs[1][tomo][i]
        nz_bs_err = npz_errs[1][tomo][i]

        z_vals_bp = zvals[2][tomo][i]
        nz_bs_bp = npzs[2][tomo][i]
        nz_bs_bp_err = npz_errs[2][tomo][i]

        z_vals_bp_mag = zvals[3][tomo][i]
        nz_bs_bp_mag = npzs[3][tomo][i]
        nz_bs_bp_mag_err = npz_errs[3][tomo][i]

        # sanity check: bp and bp_mag z-grids should match
        assert np.allclose(z_vals_bp, z_vals_bp_mag)

        for j in range(len(z_vals_bp)):
            data_rows.append(
                {
                    "tomo_bin": tomo,
                    "tracer": tracer,
                    "redshift": z_vals_bp[j],
                    "npz_cross": None,
                    "npz_cross_err": None,
                    "npz_bs": nz_bs[j],
                    "npz_bs_err": nz_bs_err[j],
                    "npz_bs_bp": nz_bs_bp[j],
                    "npz_bs_bp_err": nz_bs_bp_err[j],
                    "npz_bs_bp_mag": nz_bs_bp_mag[j],
                    "npz_bs_bp_mag_err": nz_bs_bp_mag_err[j],
                }
            )

df = pd.DataFrame(data_rows)
patches = [1, 2, 3, 4]

path_dict_metadata = {}
for tomo in [1]:
    stem = "calibration_bin5/dr2"
    path_dict_metadata[f"tomo_{tomo}"] = {
        "HSC": str(CORR_ROOT / "v12_correction" / f"autos_HSC"),
        "DESI_NGC": str(CORR_ROOT / stem / f"autos_NGC"),
        "DESI_SGC": str(CORR_ROOT / stem / f"autos_SGC"),
        "DESIxHSC": str(CORR_ROOT / stem / f"cross"),
        "stem": stem,
    }

metadata = {
    "scale_cuts": scale_cut,
    "patches": patches,
    "path_dictionaries": path_dict_metadata,
    "creation_date": datetime.now().isoformat(),
    "description": "Magnification corrected and raw n(z) measurements for DESI tracers across HSC tomographic bins",
    "tracers_by_tomo": tomo_to_tracer,
}

output_file = (
    Path(RESULTS_ROOT) / f"nz_res_{scale_cut[0]}_{scale_cut[1]}_{version}.parquet"
)
df.to_parquet(output_file, index=False)

metadata_file = (
    Path(RESULTS_ROOT) / f"nz_res_metadata_{scale_cut[0]}_{scale_cut[1]}_{version}.json"
)
with open(metadata_file, "w") as f:
    json.dump(metadata, f, indent=2)

print(df.head(10))
# Out:
#    tomo_bin  tracer  redshift  npz_cross  npz_cross_err  npz_bs_bp  \
# 0         1  Merged     0.725   0.081771       0.157855        NaN
# 1         1  Merged     0.775  -0.183734       0.151558        NaN
# 2         1  Merged     0.825   0.026715       0.153322        NaN
# 3         1  Merged     0.875   0.022105       0.142928        NaN
# 4         1  Merged     0.925  -0.122656       0.111087        NaN
# 5         1  Merged     0.975  -0.021120       0.129031        NaN
# 6         1  Merged     1.025  -0.056514       0.128409        NaN
# 7         1  Merged     1.075   0.084131       0.120983        NaN
# 8         1  Merged     1.125  -0.020170       0.136125        NaN
# 9         1  Merged     1.175   0.110691       0.138064        NaN
#
#    npz_bs_bp_err  npz_bs_bp_mag  npz_bs_bp_mag_err  npz_bs  npz_bs_err
# 0            NaN            NaN                NaN     NaN         NaN
# 1            NaN            NaN                NaN     NaN         NaN
# 2            NaN            NaN                NaN     NaN         NaN
# 3            NaN            NaN                NaN     NaN         NaN
# 4            NaN            NaN                NaN     NaN         NaN
# 5            NaN            NaN                NaN     NaN         NaN
# 6            NaN            NaN                NaN     NaN         NaN
# 7            NaN            NaN                NaN     NaN         NaN
# 8            NaN            NaN                NaN     NaN         NaN
# 9            NaN            NaN                NaN     NaN         NaN

# %%
print(f"Scale cut {scale_cut[0]} - {scale_cut[1]} Mpc/h results saved to {output_file}")
data = pd.read_parquet(
    f"{RESULTS_ROOT}/nz_res_{scale_cut[0]}_{scale_cut[1]}_{version}.parquet"
)
print(data.columns)
# Out:
# Scale cut 1 - 5 Mpc/h results saved to /global/cfs/cdirs/desicollab/users/jchdj/desi-y3-hsc/results/calibration_bin5/nz_res_1_5_vBin5.parquet
# Index(['tomo_bin', 'tracer', 'redshift', 'npz_cross', 'npz_cross_err',
#        'npz_bs_bp', 'npz_bs_bp_err', 'npz_bs_bp_mag', 'npz_bs_bp_mag_err',
#        'npz_bs', 'npz_bs_err'],
#       dtype='object')

# %%
importlib.reload(inference)
merged = {"1": {}, "2": {}, "3": {}, "4": {}}
names = ["npz_cross", "npz_bs", "npz_bs_bp", "npz_bs_bp_mag"]

# %%
for name in names:
    for tomo in [1]:
        data_tomo = data[data["tomo_bin"] == tomo]
        tracers = list(set(data_tomo["tracer"]))
        zv = [data_tomo["redshift"][data_tomo["tracer"] == t].values for t in tracers]
        _npz = [data_tomo[name][data_tomo["tracer"] == t].values for t in tracers]
        _npz_err = [
            data_tomo[name + "_err"][data_tomo["tracer"] == t].values for t in tracers
        ]

        zmt_raw, npmt, npmt_err = inference.merge_results(zv, _npz, _npz_err)
        merged[str(tomo)].update(
            {
                name + "_z": zmt_raw,
                name: npmt,
                name + "_err": npmt_err,
            }
        )
    merged[str(tomo)]["z"] = zmt_raw
save_dict = {
    f"{tomo}/{k}": np.array(v) for tomo, d in merged.items() for k, v in d.items()
}
np.savez_compressed(
    f"{RESULTS_ROOT}/merged_res_{scale_cut[0]}_{scale_cut[1]}_{version}.npz",
    **save_dict,
)

# %%
# renormalization and plotting
tbl = np.load(f"{RESULTS_ROOT}/merged_res_{scale_cut[0]}_{scale_cut[1]}_{version}.npz")
tomo_bins = [1]
bounds = {"1": (0.7, 2.85), "2": (0.3, 1.3), "3": (0.3, 2.1), "4": (0.7, 2.1)}
names = ["npz_cross", "npz_bs", "npz_bs_bp", "npz_bs_bp_mag"]
norm_tbl = {}
for tomo in tomo_bins:
    for na in names:
        zn = tbl[f"{tomo}/{na}_z"]
        z_mask = (zn >= bounds[str(tomo)][0]) & (zn <= bounds[str(tomo)][1])
        np_z = tbl[f"{tomo}/{na}"][z_mask]
        np_z_err = tbl[f"{tomo}/{na}_err"][z_mask]

        # one has to renormalize by the integral over the range for cases
        amplitude = np.trapezoid(np_z, zn[z_mask])

        norm_tbl[f"{tomo}/{na}_z"] = zn[z_mask]
        norm_tbl[f"{tomo}/{na}"] = np_z / amplitude
        norm_tbl[f"{tomo}/{na}_err"] = np_z_err / amplitude

        plt.errorbar(
            zn[z_mask],
            norm_tbl[f"{tomo}/{na}"],
            norm_tbl[f"{tomo}/{na}_err"],
            capsize=3,
            label=f"n(z) {na}",
            linestyle="",
            marker="s",
            ms=4,
        )
    plt.axhline(0, color="k", linestyle="--", linewidth=1)
    plt.grid(True)
    plt.xlabel("Redshift")
    plt.ylabel("Normalized n(z)")

if len(tomo_bins) == 1:
    plt.legend()
plt.title(f"version : {version}")
np.savez_compressed(
    f"{RESULTS_ROOT}/merged_res_norm_{scale_cut[0]}_{scale_cut[1]}_{version}.npz",
    **norm_tbl,
)

# %%
RESULTS_ROOT = ROOT / "results" / "calibration_bin5"
version = 'vBin5'
tbl_03_3 = np.load(f"{RESULTS_ROOT}/merged_res_norm_0.3_3_{version}.npz")
tbl_1_5 = np.load(f"{RESULTS_ROOT}/merged_res_norm_1_5_{version}.npz")

# %%
with pm.make_plot("bin5", figsize=(8, 4), tight_layout=False, show=True) as (fig, ax):
    corrections = 'bs_bp_mag'
    z_key = f'1/npz_{corrections}_z'
    nz_key = f'1/npz_{corrections}'
    nz_err_key = f'1/npz_{corrections}_err'
    mpch = r"h$^{-1}$Mpc"
    ax.axhline(0, color='black', linewidth=0.8, linestyle='--', alpha=0.7)
    ax.errorbar(
        tbl_03_3[z_key]+0.003, 
        tbl_03_3[nz_key], 
        tbl_03_3[nz_err_key], 
        color='darkturquoise', 
        capsize=3, 
        label='0.3-3 ' + mpch, 
        marker="d", 
        markersize=6,
        linestyle='',
        capthick=2
        )
    ax.errorbar(
        tbl_1_5[z_key]-0.003, 
        tbl_1_5[nz_key], 
        tbl_1_5[nz_err_key], 
        color='navy', 
        capsize=3, 
        label='1-5 ' + mpch, 
        alpha=0.7, 
        marker="s", 
        markersize=5,
        linestyle='',
        capthick=2
        )
    ax.axvline(1.8, color='forestgreen', linewidth=2, alpha=0.5, linestyle='-.')
    ax.axvline(2, color='forestgreen', linewidth=2, alpha=0.5, linestyle='-.')
    ax.legend(loc='upper left')
    ax.set_ylim(-1.5, 4.2)
    ax.set_xlim(1., 2.6)
    ax.set_xlabel('Redshift (z)')
    ax.set_ylabel('n(z)')

# %%
RESULTS_ROOT = ROOT / "results"
version = 'vF'
tbl_03_3 = np.load(f"{RESULTS_ROOT}/distributions/0.3_3/merged_res_norm_0.3_3_{version}.npz")
tbl_1_5 = np.load(f"{RESULTS_ROOT}/distributions/1_5/merged_res_norm_1_5_{version}.npz")

# %%
corrections = 'cross'
z_key = f'4/npz_{corrections}_z'
nz_key = f'4/npz_{corrections}'
nz_err_key = f'4/npz_{corrections}_err'

plt.axhline(0, color='black', linewidth=0.8, linestyle='--', alpha=0.7)
plt.errorbar(tbl_03_3[z_key], tbl_03_3[nz_key], tbl_03_3[nz_err_key], color='royalblue', capsize=3, label='0.3-3 ' + mpch)
plt.errorbar(tbl_1_5[z_key], tbl_1_5[nz_key], tbl_1_5[nz_err_key], color='crimson', capsize=3, label='1-5 ' + mpch)
plt.axvline(1.2, color='darkcyan', linewidth=2, alpha=0.3)
plt.axvline(1.5, color='darkcyan', linewidth=2, alpha=0.3, label='Tomographic bin bounds')
plt.legend(loc='upper right')
plt.xlim(0.8, 2.1)
plt.ylim(-1.5, 5.5)
# Out:
# (-1.5, 5.5)
